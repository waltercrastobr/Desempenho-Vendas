# %% [markdown]
# # Análise Exploratória de Dados (EDA) da TechSales Inc.
#
# ## Descrição do Cenário
#
# A TechSales Inc., uma empresa de tecnologia, está enfrentando desafios para atingir suas metas de vendas. A empresa utiliza um sistema CRM para gerenciar suas interações com clientes, atividades de vendas e oportunidades de negócio. Apesar de ter uma equipe de vendas dedicada, a TechSales Inc. tem encontrado dificuldades para aumentar sua taxa de conversão de oportunidades em negócios fechados e maximizar o valor das vendas.
#
# Recentemente, a empresa coletou um conjunto robusto de dados que inclui informações detalhadas sobre clientes, atividades de vendas, oportunidades de negócio, desempenho da equipe de vendas e características dos produtos oferecidos. A liderança da empresa acredita que, com uma análise detalhada desses dados, será possível identificar padrões e tendências que possam ajudar a melhorar o desempenho de vendas e orientar estratégias mais eficazes.
#
# ## Problema a Ser Resolvido
#
# A TechSales Inc. precisa de sua ajuda para entender os fatores que influenciam o sucesso das vendas e identificar oportunidades de melhoria. A empresa quer respostas para perguntas do tipo:
#
# 1. Quais são os principais fatores que determinam se uma oportunidade será ganha ou perdida?
# 2. Quais produtos têm maior impacto nas vendas e como podemos otimizar nosso portfólio de produtos?
# 3. Como o desempenho das diferentes equipes de vendas varia e o que podemos aprender com as equipes de melhor desempenho?
# 4. Quais características dos clientes estão mais associadas ao fechamento de negócios e como podemos segmentar nossos esforços de vendas para melhor atender a esses clientes?
#
# Neste notebook, vamos conduzir uma análise exploratória dos dados (EDA) para investigar essas questões e fornecer insights valiosos para a TechSales Inc.

# %% [markdown]
# ## Conhecendo as bases
#
# Vamos começar nossa análise exploratória de dados (EDA) examinando cada um dos conjuntos de dados. O objetivo é obter uma compreensão abrangente dos dados, incluindo informações gerais e estatísticas descritivas. Durante essa exploração, também identificaremos e trataremos potenciais problemas, como dados nulos e registros duplicados.

# %% [markdown]
# Vamos começar importando as bibliotecas necessárias para nossa análise exploratória de dados (EDA). Estaremos utilizando o pandas para manipulação dos dados, numpy para operações numéricas, seaborn e matplotlib.pyplot para visualização dos dados, e datetime para lidar com datas.

# %%
# Importando as Bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# Agora vamos importar as bases de dados que iremos analisar. Estaremos utilizando os seguintes arquivos CSV: accounts, products, sales_pipeline, sales_team e dicionario. Vamos carregar esses arquivos para os respectivos dataframes.

# %%
# Importando as bases de dados
accounts = pd.read_csv('/content/accounts.csv')
products = pd.read_csv('/content/products.csv')
sales_pipeline = pd.read_csv('/content/sales_pipeline.csv')
sales_team = pd.read_csv('/content/sales_teams.csv')
dicionario = pd.read_csv('/content/data_dictionary.csv')

# %% [markdown]
# Vamos dar uma olhada nas primeiras linhas da base de dados "accounts" para entender melhor sua estrutura e os tipos de informações que ela contém. Isso nos ajudará a ter uma ideia inicial do que podemos explorar.

# %%
# Verificando a base
accounts.head()
# Out:
#             account     sector  year_established  revenue  employees  \
# 0  Acme Corporation  technolgy              1996  1100.04       2822
# 1        Betasoloin    medical              1999   251.41        495
# 2          Betatech    medical              1986   647.18       1185
# 3        Bioholding    medical              2012   587.34       1356
# 4           Bioplex    medical              1991   326.82       1016
#
#   office_location subsidiary_of
# 0   United States           NaN
# 1   United States           NaN
# 2           Kenya           NaN
# 3      Philipines           NaN
# 4   United States           NaN

# %% [markdown]
# Vamos verificar quantas linhas e colunas a base de dados "accounts" possui. Isso nos dará uma ideia da quantidade de registros e variáveis que estamos lidando.

# %%
# Verificando tamanho (dimensões)
accounts.shape
# Out:
# (85, 7)

# %% [markdown]
# Agora seguimos o mesmo processo para as outras bases.

# %%
# Verificando a base
products.head()
# Out:
#         product series  sales_price
# 0     GTX Basic    GTX          550
# 1       GTX Pro    GTX         4821
# 2    MG Special     MG           55
# 3   MG Advanced     MG         3393
# 4  GTX Plus Pro    GTX         5482

# %%
# Verificando tamanho
products.shape
# Out:
# (7, 3)

# %%
# Verificando a base
sales_pipeline.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date  close_date  close_value
# 0  2016-10-20  2017-03-01       1054.0
# 1  2016-10-25  2017-03-11       4514.0
# 2  2016-10-25  2017-03-07         50.0
# 3  2016-10-25  2017-03-09        588.0
# 4  2016-10-25  2017-03-02        517.0

# %%
# Verificando o tamanho
sales_pipeline.shape
# Out:
# (8800, 8)

# %%
# Verificando a base
sales_team.head()
# Out:
#          sales_agent           manager regional_office
# 0      Anna Snelling  Dustin Brinkmann         Central
# 1     Cecily Lampkin  Dustin Brinkmann         Central
# 2  Versie Hillebrand  Dustin Brinkmann         Central
# 3    Lajuana Vencill  Dustin Brinkmann         Central
# 4        Moses Frase  Dustin Brinkmann         Central

# %%
# verificando o tamanho
sales_team.shape
# Out:
# (35, 3)

# %%
# Verificando a base
dicionario.head(21)
# Out:
#              Table             Field  \
# 0         accounts           account
# 1         accounts            sector
# 2         accounts  year_established
# 3         accounts           revenue
# 4         accounts         employees
# 5         accounts   office_location
# 6         accounts     subsidiary_of
# 7         products           product
# 8         products            series
# 9         products       sales_price
# 10     sales_teams       sales_agent
# 11     sales_teams           manager
# 12     sales_teams   regional_office
# 13  sales_pipeline    opportunity_id
# 14  sales_pipeline       sales_agent
# 15  sales_pipeline           product
# 16  sales_pipeline           account
# 17  sales_pipeline        deal_stage
# 18  sales_pipeline       engage_date
# 19  sales_pipeline        close_date
# 20  sales_pipeline       close_value
#
#                                           Description
# 0                                        Company name
# 1                                            Industry
# 2                                    Year Established
# 3                 Annual revenue (in millions of USD)
# 4                                 Number of employees
# 5                                        Headquarters
# 6                                      Parent company
# 7                                        Product name
# 8                                      Product series
# 9                              Suggested retail price
# 10                                        Sales agent
# 11                           Respective sales manager
# 12                                    Regional office
# 13                                  Unique identifier
# 14                                       Sales agent
# 15                                       Product name
# 16                                       Company name
# 17  Sales pipeline stage (Prospecting > Engaging >...
# 18  Date in which the "Engaging" deal stage was in...
# 19         Date in which the deal was "Won" or "Lost"
# 20                              Revenue from the deal

# %%
# Verificando o tamanho
dicionario.shape
# Out:
# (21, 3)

# %% [markdown]
# ## Tratando cada base de dados
#
# Após importarmos as bases de dados, avançamos para a etapa de tratamento de cada uma delas. Aqui, buscamos obter dados limpos e preparados para a análise exploratória, visando a geração de insights valiosos. Além disso, estamos criando um dicionário de dados para cada base, o que nos ajudará a entender melhor o significado de cada variável.

# %% [markdown]
# ### Accounts

# %%
# Verificando a base
accounts.head()
# Out:
#             account     sector  year_established  revenue  employees  \
# 0  Acme Corporation  technolgy              1996  1100.04       2822
# 1        Betasoloin    medical              1999   251.41        495
# 2          Betatech    medical              1986   647.18       1185
# 3        Bioholding    medical              2012   587.34       1356
# 4           Bioplex    medical              1991   326.82       1016
#
#   office_location subsidiary_of
# 0   United States           NaN
# 1   United States           NaN
# 2           Kenya           NaN
# 3      Philipines           NaN
# 4   United States           NaN

# %%
# Verificando informações
accounts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   account           85 non-null     object
#  1   sector            85 non-null     object
#  2   year_established  85 non-null     int64
#  3   revenue           85 non-null     float64
#  4   employees         85 non-null     int64
#  5   office_location   85 non-null     object
#  6   subsidiary_of     15 non-null     object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 4.8+ KB

# %% [markdown]
# **Dicionário de Dados**
#
# - account: Nome da empresa
# - sector: Setor de atuação da empresa
# - year_established: Ano de fundação da empresa
# - revenue: Receita da empresa em milhões de dólares
# - employees: Número de funcionários da empresa
# - office_location: Localização do escritório principal da empresa
# - subsidiary_of: Nome da empresa-mãe, se houver

# %%
# Verificando um resumo estatístico que nos ajuda a perceber, no primeiro momento, a distribui
accounts.describe()
# Out:
#        year_established       revenue     employees
# count         85.000000     85.000000     85.000000
# mean        1996.105882   1994.632941   4660.823529
# std            8.865427   2169.491436   5715.601198
# min         1979.000000      4.540000      9.000000
# 25%         1989.000000    497.110000   1179.000000
# 50%         1996.000000   1223.720000   2769.000000
# 75%         2002.000000   2741.370000   5595.000000
# max         2017.000000  11698.030000  34288.000000

# %% [markdown]
# Os dados numéricos parecem estar dentro de métricas aceitáveis no geral. No entanto, é intrigante o número mínimo de 9 funcionários em relação à média, especialmente para uma empresa que gera mais de 4 milhões em vendas. Vamos investigar mais a fundo esses dados para essas empresas.

# %%
# Verificando dados duplicados
accounts[accounts.duplicated()]
# Out:
# Empty DataFrame
# Columns: [account, sector, year_established, revenue, employees, office_location, subsidiary_of]
# Index: []

# %% [markdown]
# Não existem colunas duplicadas

# %%
# Verificando dados nulos
accounts.isnull().sum()
# Out:
# account              0
# sector               0
# year_established     0
# revenue              0
# employees            0
# office_location      0
# subsidiary_of       70
# dtype: int64

# %% [markdown]
# Existem alguns dados nulos. Vamos tratá-los.

# %%
# Verificando na coluna específica
accounts[accounts['subsidiary_of'].isnull()]
# Out:
#              account         sector  year_established  revenue  employees  \
# 0   Acme Corporation      technolgy              1996  1100.04       2822
# 1         Betasoloin        medical              1999   251.41        495
# 2           Betatech        medical              1986   647.18       1185
# 3         Bioholding        medical              2012   587.34       1356
# 4            Bioplex        medical              1991   326.82       1016
# ..               ...            ...               ...      ...        ...
# 80        Zathunicon         retail              2010    71.12        144
# 81    Zencorporation      technolgy              2011    40.79        142
# 82            Zoomit  entertainment              1992   324.19        978
# 83           Zotware       software              1979  4478.47      13809
# 84          Zumgoity        medical              1984   441.08       1210
#
#    office_location subsidiary_of
# 0    United States           NaN
# 1    United States           NaN
# 2            Kenya           NaN
# 3       Philipines           NaN
# 4    United States           NaN
# ..             ...           ...
# 80   United States           NaN
# 81           China           NaN
# 82   United States           NaN
# 83   United States           NaN
# 84   United States           NaN
#
# [70 rows x 7 columns]

# %% [markdown]
# Para tratar os dados nulos na coluna "subsidiary_of" da base de dados "accounts", vamos substituí-los por 0, pois isso indica que são empresas novas e não possuem uma matriz anterior.

# %%
# Substituindo
accounts['subsidiary_of'].fillna(0, inplace=True)

# Verificando
accounts.isnull().sum()
# Out:
# account             0
# sector              0
# year_established    0
# revenue             0
# employees           0
# office_location     0
# subsidiary_of       0
# dtype: int64

# %% [markdown]
# Vamos fazer a investigação proposta anteriormente para verificar os casos de empresas pequenas com lucros altos

# %%
# Investigando as empresas com poucos funcionários (menos que a média)
accounts.loc[accounts['employees'] < 4660]
# Out:
#                          account              sector  year_established  \
# 0               Acme Corporation           technolgy              1996
# 1                     Betasoloin             medical              1999
# 2                       Betatech             medical              1986
# 3                     Bioholding             medical              2012
# 4                        Bioplex             medical              1991
# 5                       Blackzim              retail              2009
# 6                  Bluth Company           technolgy              1993
# 7                     Bubba Gump            software              2002
# 8                        Cancity              retail              2001
# 10                       Codehow            software              1998
# 11                        Condax             medical              2017
# 12                       Conecom           technolgy              2005
# 13                Dalttechnology            software              2013
# 14                       dambase           marketing              1995
# 15                       Domzoom       entertainment              1998
# 16                        Doncon           technolgy              2010
# 17                   Donquadtech           technolgy              1992
# 19                       Donware           marketing              1999
# 22                       Finhigh             finance              2006
# 23                        Finjob          employment              1988
# 26                    Gekko & Co              retail              1990
# 27  Genco Pura Olive Oil Company              retail              2007
# 28            Globex Corporation           technolgy              2000
# 29                      Gogozoom  telecommunications              2007
# 30                       Golddex             finance              2008
# 32                    Green-Plus            services              2003
# 33                  Groovestreet              retail              2003
# 34                        Hatfan            services              1982
# 38                         Isdom             medical              2002
# 39                   Iselectrics           technolgy              2011
# 40                       J-Texon              retail              1989
# 42                    Kinnamplus              retail              2004
# 44                     Konmatfix           marketing              1985
# 46                    Lexiqvolax             medical              2004
# 47               Massive Dynamic       entertainment              1989
# 49                       Nam-zim            services              1987
# 50                         Newex            services              1991
# 51                     Ontomedia          employment              1997
# 52                      Opentech             finance              1994
# 54                     Plusstrip       entertainment              2002
# 55                     Plussunin              retail              2003
# 57                      Rantouch  telecommunications              1994
# 59                     Rundofase           technolgy              1983
# 61                      Scottech           marketing              2012
# 65                    Stanredtax             finance              1987
# 66                  Statholdings          employment              1997
# 67                     Streethex              retail              1988
# 68                        Sumace              retail              2000
# 69                    Sunnamplex           marketing              2008
# 70         The New York Inquirer             medical              1996
# 71                      Toughzap              retail              1995
# 74     Vehement Capital Partners             finance              1993
# 79                        Yearin              retail              2005
# 80                    Zathunicon              retail              2010
# 81                Zencorporation           technolgy              2011
# 82                        Zoomit       entertainment              1992
# 84                      Zumgoity             medical              1984
#
#     revenue  employees office_location     subsidiary_of
# 0   1100.04       2822   United States                 0
# 1    251.41        495   United States                 0
# 2    647.18       1185           Kenya                 0
# 3    587.34       1356      Philipines                 0
# 4    326.82       1016   United States                 0
# 5    497.11       1588   United States                 0
# 6   1242.32       3027   United States  Acme Corporation
# 7    987.39       2253   United States                 0
# 8    718.62       2448   United States                 0
# 10  2714.90       2641   United States  Acme Corporation
# 11     4.54          9   United States                 0
# 12  1520.66       1806   United States                 0
# 13    98.79         96   United States        Bubba Gump
# 14  2173.98       2928   United States             Inity
# 15   217.87        551   United States                 0
# 16   587.72       1501   United States                 0
# 17  1712.68       3194   United States  Acme Corporation
# 19  1197.44       2570   United States                 0
# 22  1102.43       1759   United States                 0
# 23  2059.90       3644   United States                 0
# 26  2520.83       3502   United States                 0
# 27   894.33       1635           Italy                 0
# 28  1223.72       2497          Norway                 0
# 29    86.68        187   United States            Sonron
# 30    52.50        165   United States                 0
# 32   692.19       1922   United States                 0
# 33   223.80        299   United States                 0
# 34   792.46       1299   United States                 0
# 38  3178.24       4540   United States                 0
# 39   527.11       1428   United States  Acme Corporation
# 40  1388.67       3583   United States                 0
# 42   702.72       1831   United States                 0
# 44   375.43       1190   United States                 0
# 46  1618.89       3889   United States                 0
# 47   665.06       1095   United States                 0
# 49   405.59       1179          Brazil         Warephase
# 50  1012.72       3492         Germany                 0
# 51   882.12       2769   United States                 0
# 52   355.23        853   United States                 0
# 54   349.81        315   United States                 0
# 55  1419.98       4018   United States                 0
# 57  1188.42       3015   United States                 0
# 59  1008.06       1238   United States                 0
# 61    45.39        100   United States             Inity
# 65  1698.20       3798   United States                 0
# 66   291.27        586   United States                 0
# 67  1376.80       1165         Belgium                 0
# 68   167.89        493         Romania                 0
# 69   894.37       1593          Poland                 0
# 70   439.21        792   United States                 0
# 71   332.43        799   United States                 0
# 74   646.10        883   United States           Golddex
# 79  2261.05       3851   United States                 0
# 80    71.12        144   United States                 0
# 81    40.79        142           China                 0
# 82   324.19        978   United States                 0
# 84   441.08       1210   United States                 0

# %% [markdown]
# Notamos que os valores mais baixos (abaixo de 100) estão associados aos setores de software e medicina, que geralmente oferecem produtos caros. Isso pode explicar o alto faturamento, apesar do número limitado de profissionais nessas áreas.

# %% [markdown]
# ### Products

# %%
# Verificando a base
products.head(7)
# Out:
#           product series  sales_price
# 0       GTX Basic    GTX          550
# 1         GTX Pro    GTX         4821
# 2      MG Special     MG           55
# 3     MG Advanced     MG         3393
# 4    GTX Plus Pro    GTX         5482
# 5  GTX Plus Basic    GTX         1096
# 6         GTK 500    GTK        26768

# %% [markdown]
# Percebemos que o valor da placa GTK 500 parece estar muito acima do esperado. É importante verificar essa informação para garantir que não haja erros nos dados.

# %% [markdown]
# **Dicionário de Dados**
#
# - product: Descrição do produto.
# - series: Série do produto.
# - sales_price: Preço de venda do produto.

# %%
# Verificando informações
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product      7 non-null      object
#  1   series       7 non-null      object
#  2   sales_price  7 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %%
# Verificando um resumo estatístico
products.describe()
# Out:
#         sales_price
# count      7.000000
# mean    6023.571429
# std     9388.428070
# min       55.000000
# 25%      823.000000
# 50%     3393.000000
# 75%     5151.500000
# max    26768.000000

# %%
# Verificando dados duplicados
products[products.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product, series, sales_price]
# Index: []

# %%
# Verificando dados nulos
products.isnull().sum()
# Out:
# product        0
# series         0
# sales_price    0
# dtype: int64

# %% [markdown]
# Não existem dados nulos ou duplicados

# %%
# Pegando os dados da tabela sales_pipeline para verificar os dados de venda da placa GTK 500
indice = sales_pipeline.index[sales_pipeline['product'] == 'GTK 500'].tolist()
sales_pipeline.iloc[indice]
# Out:
#      opportunity_id        sales_agent  product                    account  \
# 59         XUSUEAV7       Elease Gluck  GTK 500                     Zoomit
# 266        125VIRMX       Elease Gluck  GTK 500                  Warephase
# 653        A7SA2L21       Elease Gluck  GTK 500                        NaN
# 677        60UOBOEM    Rosalina Dieter  GTK 500               Groovestreet
# 681        IXOHJYRM       Elease Gluck  GTK 500                     Cheers
# 751        YFB7Y92U       Elease Gluck  GTK 500                        NaN
# 876        SCS5H8V1     Markita Hansen  GTK 500  Vehement Capital Partners
# 1156       4V0S4BA3     Markita Hansen  GTK 500                 Goodsilron
# 1548       PEX6S873       Elease Gluck  GTK 500                     Cheers
# 1677       OBBVVO9O       Elease Gluck  GTK 500               Singletechno
# 1825       JXUXBANJ    Rosalina Dieter  GTK 500              Y-corporation
# 1921       LUFY70BU       Elease Gluck  GTK 500                 Goodsilron
# 2151       AKMV6WN5       Elease Gluck  GTK 500                        NaN
# 2522       DJMPI9TO       Elease Gluck  GTK 500                   Xx-zobam
# 2559       OUIK8VX3       Elease Gluck  GTK 500                 Lexiqvolax
# 2586       K0T5LJ3E       Elease Gluck  GTK 500                    Plexzap
# 2808       731TOWDY       Elease Gluck  GTK 500                   Labdrill
# 3038       GL1YE4PQ     Markita Hansen  GTK 500                        NaN
# 3261       N3GVE0VP     Markita Hansen  GTK 500                        NaN
# 3352       TB27K4GC     Markita Hansen  GTK 500                     Finjob
# 3495       83JP1K4E    Rosalina Dieter  GTK 500                   Rantouch
# 3522       4X3H9YD5    Rosalina Dieter  GTK 500                   Kan-code
# 3808       GG85QBTM       Elease Gluck  GTK 500                 Lexiqvolax
# 3839       LSJ2A8ZX     Markita Hansen  GTK 500                     Cheers
# 3911       5URQT67R     Markita Hansen  GTK 500                  Treequote
# 3925       6X4EEUGA       Elease Gluck  GTK 500                     Cheers
# 3976       CQZSFN7C     Markita Hansen  GTK 500                      Konex
# 4710       CQW6TYOX    Rosalina Dieter  GTK 500                     Cheers
# 5174       021Z2J9L     Markita Hansen  GTK 500                  Rundofase
# 5383       9SRD5NCR    Rosalina Dieter  GTK 500                        NaN
# 5588       DO6VKC2G  Marty Freudenburg  GTK 500                        NaN
# 5636       A04V2WB3       Elease Gluck  GTK 500                        NaN
# 6420       1H2PVLZ3    Rosalina Dieter  GTK 500                 Xx-holding
# 7051       1LY8CAXD    Rosalina Dieter  GTK 500                 Betasoloin
# 7265       6WIQG92N       Elease Gluck  GTK 500                      Konex
# 7730       4MXSHU7X      Corliss Cosme  GTK 500                   Kan-code
# 7829       PP4ZY6TZ    Darcel Schlecht  GTK 500                  Treequote
# 7848       H3K2E35I       Elease Gluck  GTK 500                     Cheers
# 7997       ZSYWCL6R     Markita Hansen  GTK 500                 Xx-holding
# 8078       GB6C2UK5       Elease Gluck  GTK 500                 Xx-holding
#
#      deal_stage engage_date  close_date  close_value
# 59          Won  2016-11-20  2017-03-09      25897.0
# 266    Engaging  2016-12-19         NaN          NaN
# 653    Engaging  2017-01-30         NaN          NaN
# 677         Won  2017-02-01  2017-06-07      30288.0
# 681        Lost  2017-02-02  2017-05-09          0.0
# 751    Engaging  2017-02-07         NaN          NaN
# 876    Engaging  2017-02-14         NaN          NaN
# 1156        Won  2017-02-27  2017-06-27      29617.0
# 1548       Lost  2017-03-15  2017-05-19          0.0
# 1677       Lost  2017-03-20  2017-05-27          0.0
# 1825        Won  2017-03-26  2017-04-05      25288.0
# 1921       Lost  2017-03-30  2017-04-04          0.0
# 2151   Engaging  2017-04-06         NaN          NaN
# 2522   Engaging  2017-04-18         NaN          NaN
# 2559        Won  2017-04-19  2017-04-20      23746.0
# 2586        Won  2017-04-20  2017-06-28      24949.0
# 2808        Won  2017-04-28  2017-06-18      27385.0
# 3038   Engaging  2017-05-09         NaN          NaN
# 3261   Engaging  2017-05-18         NaN          NaN
# 3352        Won  2017-05-22  2017-08-14      24745.0
# 3495        Won  2017-05-28  2017-08-28      24899.0
# 3522        Won  2017-05-29  2017-08-29      25791.0
# 3808   Engaging  2017-06-10         NaN          NaN
# 3839        Won  2017-06-11  2017-09-26      29166.0
# 3911   Engaging  2017-06-14         NaN          NaN
# 3925        Won  2017-06-15  2017-06-30      25464.0
# 3976       Lost  2017-06-17  2017-08-15          0.0
# 4710       Lost  2017-07-11  2017-07-18          0.0
# 5174   Engaging  2017-07-23         NaN          NaN
# 5383   Engaging  2017-07-27         NaN          NaN
# 5588   Engaging  2017-08-01         NaN          NaN
# 5636   Engaging  2017-08-03         NaN          NaN
# 6420        Won  2017-09-03  2017-11-10      26186.0
# 7051   Engaging  2017-09-27         NaN          NaN
# 7265       Lost  2017-10-05  2017-10-18          0.0
# 7730       Lost  2017-10-22  2017-11-30          0.0
# 7829       Lost  2017-10-27  2017-11-10          0.0
# 7848        Won  2017-10-28  2017-10-29      27971.0
# 7997       Lost  2017-11-10  2017-11-26          0.0
# 8078        Won  2017-11-18  2017-12-04      29220.0

# %% [markdown]
# Podemos observar que o valor da placa GTK 500 está bastante elevado, e após verificação, confirmamos que esse preço está correto e não se trata de um erro nos dados. Essa informação pode ser relevante para análises posteriores, destacando a natureza premium desse produto em relação aos demais.

# %% [markdown]
# ### Sales Pipeline

# %%
# Verificando a base
sales_pipeline.head()
# Out:
#   opportunity_id      sales_agent         product  account deal_stage  \
# 0       1C1I7A6R      Moses Frase  GTX Plus Basic  Cancity        Won
# 1       Z063OYW0  Darcel Schlecht          GTXPro    Isdom        Won
# 2       EC4QE1BX  Darcel Schlecht      MG Special  Cancity        Won
# 3       MV1LWRNH      Moses Frase       GTX Basic  Codehow        Won
# 4       PE84CX4O        Zane Levy       GTX Basic   Hatfan        Won
#
#   engage_date  close_date  close_value
# 0  2016-10-20  2017-03-01       1054.0
# 1  2016-10-25  2017-03-11       4514.0
# 2  2016-10-25  2017-03-07         50.0
# 3  2016-10-25  2017-03-09        588.0
# 4  2016-10-25  2017-03-02        517.0

# %% [markdown]
# **Dicionário de Dados**
#
# - opportunity_id: Identificador único para cada oportunidade de venda.
# - sales_agent: Nome do agente de vendas responsável pela oportunidade.
# - product: Nome do produto associado à oportunidade de venda.
# - account: Nome da conta ou cliente associado à oportunidade de venda.
# - deal_stage: Estágio atual do negócio (por exemplo, Engajando, Perdido, Ganho).
# - engage_date: Data em que a oportunidade foi engajada.
# - close_date: Data em que a oportunidade foi fechada (se aplicável).
# - close_value: Valor da venda quando a oportunidade é fechada (se aplicável).

# %%
# Verificando a base
sales_pipeline.tail()
# Out:
#      opportunity_id        sales_agent      product account   deal_stage  \
# 8795       9MIWFW5J  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8796       6SLKZ8FI  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8797       LIB4KUZJ  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8798       18IUIUK0  Versie Hillebrand  MG Advanced     NaN  Prospecting
# 8799       8I5ONXJX  Versie Hillebrand  MG Advanced     NaN  Prospecting
#
#      engage_date close_date  close_value
# 8795         NaN        NaN          NaN
# 8796         NaN        NaN          NaN
# 8797         NaN        NaN          NaN
# 8798         NaN        NaN          NaN
# 8799         NaN        NaN          NaN

# %% [markdown]
# Percebe-se que, apesar de o ID da oportunidade ser diferente, há a presença de dados duplicados nessa tabela, possivelmente devido ao registro de múltiplas oportunidades para o mesmo negócio. Vamos proceder com a exclusão da coluna 'opportunity_id' e remover os dados duplicados para manter nossa base limpa e sem redundâncias.

# %%
# Verificando informações
sales_pipeline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8800 entries, 0 to 8799
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   opportunity_id  8800 non-null   object
#  1   sales_agent     8800 non-null   object
#  2   product         8800 non-null   object
#  3   account         7375 non-null   object
#  4   deal_stage      8800 non-null   object
#  5   engage_date     8300 non-null   object
#  6   close_date      6711 non-null   object
#  7   close_value     6711 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 550.1+ KB

# %%
# Verificando um resumo estatístico
sales_pipeline.describe()
# Out:
#         close_value
# count   6711.000000
# mean    1490.915512
# std     2320.670773
# min        0.000000
# 25%        0.000000
# 50%      472.000000
# 75%     3225.000000
# max    30288.000000

# %%
# Excluindo coluna ID
sales_pipeline = sales_pipeline.drop(sales_pipeline.columns[0], axis=1)

# %%
# Verificando dados duplicados após a exclusão da coluna ID
sales_pipeline[sales_pipeline.duplicated()]
# Out:
#             sales_agent         product account   deal_stage engage_date  \
# 1122    Maureen Marcano  GTX Plus Basic     NaN     Engaging  2017-02-26
# 1437    Kary Hendrixson       GTX Basic     NaN     Engaging  2017-03-10
# 1615   Violet Mclelland      MG Special     NaN     Engaging  2017-03-17
# 1875     Vicki Laflamme      MG Special     NaN     Engaging  2017-03-28
# 1876     Vicki Laflamme      MG Special     NaN     Engaging  2017-03-28
# ...                 ...             ...     ...          ...         ...
# 8795  Versie Hillebrand     MG Advanced     NaN  Prospecting         NaN
# 8796  Versie Hillebrand     MG Advanced     NaN  Prospecting         NaN
# 8797  Versie Hillebrand     MG Advanced     NaN  Prospecting         NaN
# 8798  Versie Hillebrand     MG Advanced     NaN  Prospecting         NaN
# 8799  Versie Hillebrand     MG Advanced     NaN  Prospecting         NaN
#
#      close_date  close_value
# 1122        NaN          NaN
# 1437        NaN          NaN
# 1615        NaN          NaN
# 1875        NaN          NaN
# 1876        NaN          NaN
# ...         ...          ...
# 8795        NaN          NaN
# 8796        NaN          NaN
# 8797        NaN          NaN
# 8798        NaN          NaN
# 8799        NaN          NaN
#
# [352 rows x 7 columns]

# %%
# Excluindo dados duplicados
sales_pipeline = sales_pipeline.drop_duplicates()

# %%
# Verificando se ainda existem dados duplicados
sales_pipeline[sales_pipeline.duplicated()]
# Out:
# Empty DataFrame
# Columns: [sales_agent, product, account, deal_stage, engage_date, close_date, close_value]
# Index: []

# %% [markdown]
# Agora, não há mais dados duplicados

# %%
# Verificando dados nulos
sales_pipeline.isnull().sum()
# Out:
# sales_agent       0
# product           0
# account        1079
# deal_stage        0
# engage_date     213
# close_date     1737
# close_value    1737
# dtype: int64

# %% [markdown]
# Percebemos a presença de dados nulos em algumas colunas da nossa base de dados. Vamos proceder com o tratamento desses dados para garantir a integridade e qualidade das informações.

# %%
# Account
sales_pipeline[sales_pipeline['account'].isnull()]
# Out:
#             sales_agent         product account   deal_stage engage_date  \
# 9        James Ascencio     MG Advanced     NaN     Engaging  2016-11-03
# 42        Kami Bicknell       GTX Basic     NaN     Engaging  2016-11-14
# 44         Cassey Cress          GTXPro     NaN     Engaging  2016-11-16
# 56        Kami Bicknell  GTX Plus Basic     NaN     Engaging  2016-11-19
# 60        Hayden Neloms     MG Advanced     NaN     Engaging  2016-11-20
# ...                 ...             ...     ...          ...         ...
# 8749  Versie Hillebrand       GTX Basic     NaN  Prospecting         NaN
# 8754  Versie Hillebrand  GTX Plus Basic     NaN  Prospecting         NaN
# 8755  Versie Hillebrand    GTX Plus Pro     NaN  Prospecting         NaN
# 8764  Versie Hillebrand      MG Special     NaN  Prospecting         NaN
# 8792  Versie Hillebrand     MG Advanced     NaN  Prospecting         NaN
#
#      close_date  close_value
# 9           NaN          NaN
# 42          NaN          NaN
# 44          NaN          NaN
# 56          NaN          NaN
# 60          NaN          NaN
# ...         ...          ...
# 8749        NaN          NaN
# 8754        NaN          NaN
# 8755        NaN          NaN
# 8764        NaN          NaN
# 8792        NaN          NaN
#
# [1079 rows x 7 columns]

# %% [markdown]
# Essa coluna está associada ao nome do cliente. Embora o nome do cliente não seja crucial para a análise, notamos um padrão em que, quando o nome do cliente não está presente, a venda normalmente não é consolidada. Portanto, ter informações concretas sobre o cliente pode significar uma maior probabilidade de venda. Vamos substituir esses dados nulos por 0 para representar a falta de informação do cliente.

# %%
# Substituindo
sales_pipeline['account'].fillna(0, inplace=True)

# %%
# Engage Date
sales_pipeline[sales_pipeline['engage_date'].isnull()]
# Out:
#             sales_agent         product     account   deal_stage engage_date  \
# 8300      Anna Snelling       GTX Basic  Green-Plus  Prospecting         NaN
# 8301      Anna Snelling       GTX Basic           0  Prospecting         NaN
# 8307      Anna Snelling  GTX Plus Basic   Plusstrip  Prospecting         NaN
# 8308      Anna Snelling  GTX Plus Basic    Zumgoity  Prospecting         NaN
# 8309      Anna Snelling  GTX Plus Basic           0  Prospecting         NaN
# ...                 ...             ...         ...          ...         ...
# 8763  Versie Hillebrand      MG Special   Rundofase  Prospecting         NaN
# 8764  Versie Hillebrand      MG Special           0  Prospecting         NaN
# 8790  Versie Hillebrand     MG Advanced   Ganjaflex  Prospecting         NaN
# 8791  Versie Hillebrand     MG Advanced       Silis  Prospecting         NaN
# 8792  Versie Hillebrand     MG Advanced           0  Prospecting         NaN
#
#      close_date  close_value
# 8300        NaN          NaN
# 8301        NaN          NaN
# 8307        NaN          NaN
# 8308        NaN          NaN
# 8309        NaN          NaN
# ...         ...          ...
# 8763        NaN          NaN
# 8764        NaN          NaN
# 8790        NaN          NaN
# 8791        NaN          NaN
# 8792        NaN          NaN
#
# [213 rows x 7 columns]

# %% [markdown]
# A data de engajamento da oportunidade não existe porque o cliente ainda se encontrava numa fase de prospecção. Nesse sentido, vamos substituir esses dados nulos por 0 para indicar essa situação.

# %%
# Substituindo
sales_pipeline['engage_date'].fillna(0, inplace=True)

# %%
# Close Date
sales_pipeline[sales_pipeline['close_date'].isnull()]
# Out:
#             sales_agent         product    account   deal_stage engage_date  \
# 9        James Ascencio     MG Advanced          0     Engaging  2016-11-03
# 25      Maureen Marcano     MG Advanced  Ganjaflex     Engaging  2016-11-10
# 42        Kami Bicknell       GTX Basic          0     Engaging  2016-11-14
# 44         Cassey Cress          GTXPro          0     Engaging  2016-11-16
# 56        Kami Bicknell  GTX Plus Basic          0     Engaging  2016-11-19
# ...                 ...             ...        ...          ...         ...
# 8763  Versie Hillebrand      MG Special  Rundofase  Prospecting           0
# 8764  Versie Hillebrand      MG Special          0  Prospecting           0
# 8790  Versie Hillebrand     MG Advanced  Ganjaflex  Prospecting           0
# 8791  Versie Hillebrand     MG Advanced      Silis  Prospecting           0
# 8792  Versie Hillebrand     MG Advanced          0  Prospecting           0
#
#      close_date  close_value
# 9           NaN          NaN
# 25          NaN          NaN
# 42          NaN          NaN
# 44          NaN          NaN
# 56          NaN          NaN
# ...         ...          ...
# 8763        NaN          NaN
# 8764        NaN          NaN
# 8790        NaN          NaN
# 8791        NaN          NaN
# 8792        NaN          NaN
#
# [1737 rows x 7 columns]

# %%
# Close Value
sales_pipeline[sales_pipeline['close_value'].isnull()]
# Out:
#             sales_agent         product    account   deal_stage engage_date  \
# 9        James Ascencio     MG Advanced          0     Engaging  2016-11-03
# 25      Maureen Marcano     MG Advanced  Ganjaflex     Engaging  2016-11-10
# 42        Kami Bicknell       GTX Basic          0     Engaging  2016-11-14
# 44         Cassey Cress          GTXPro          0     Engaging  2016-11-16
# 56        Kami Bicknell  GTX Plus Basic          0     Engaging  2016-11-19
# ...                 ...             ...        ...          ...         ...
# 8763  Versie Hillebrand      MG Special  Rundofase  Prospecting           0
# 8764  Versie Hillebrand      MG Special          0  Prospecting           0
# 8790  Versie Hillebrand     MG Advanced  Ganjaflex  Prospecting           0
# 8791  Versie Hillebrand     MG Advanced      Silis  Prospecting           0
# 8792  Versie Hillebrand     MG Advanced          0  Prospecting           0
#
#      close_date  close_value
# 9           NaN          NaN
# 25          NaN          NaN
# 42          NaN          NaN
# 44          NaN          NaN
# 56          NaN          NaN
# ...         ...          ...
# 8763        NaN          NaN
# 8764        NaN          NaN
# 8790        NaN          NaN
# 8791        NaN          NaN
# 8792        NaN          NaN
#
# [1737 rows x 7 columns]

# %% [markdown]
# As colunas de fechamento de negócio e valor final estão interligadas. Como o negócio não foi ou ainda não foi fechado, não é possível ter esses valores. Vamos substituir esses dados nulos por 0 para refletir essa situação.

# %%
# Substituindo
sales_pipeline['close_date'].fillna(0, inplace=True)
sales_pipeline['close_value'].fillna(0, inplace=True)

# %%
# verificando
sales_pipeline.isnull().sum()
# Out:
# sales_agent    0
# product        0
# account        0
# deal_stage     0
# engage_date    0
# close_date     0
# close_value    0
# dtype: int64

# %% [markdown]
# ### Sales Team

# %%
# Verificando a base
sales_team.head()
# Out:
#          sales_agent           manager regional_office
# 0      Anna Snelling  Dustin Brinkmann         Central
# 1     Cecily Lampkin  Dustin Brinkmann         Central
# 2  Versie Hillebrand  Dustin Brinkmann         Central
# 3    Lajuana Vencill  Dustin Brinkmann         Central
# 4        Moses Frase  Dustin Brinkmann         Central

# %% [markdown]
# **Dicionário de Dados**
#
# - sales_agent: Nome do agente de vendas.
# - manager: Nome do gerente do agente de vendas.
# - regional_office: Localização do escritório regional ao qual o agente de vendas está associado.

# %%
# Verificando informações
sales_team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sales_agent      35 non-null     object
#  1   manager          35 non-null     object
#  2   regional_office  35 non-null     object
# dtypes: object(3)
# memory usage: 968.0+ bytes

# %%
# Verificando um resumo estatístico
sales_team.describe()
# Out:
#           sales_agent        manager regional_office
# count              35             35              35
# unique             35              6               3
# top     Anna Snelling  Melvin Marxen            East
# freq                1              6              12

# %%
# Verificando dados duplicados
sales_team[sales_team.duplicated()]
# Out:
# Empty DataFrame
# Columns: [sales_agent, manager, regional_office]
# Index: []

# %%
# Verificando dados nulos
sales_team.isnull().sum()
# Out:
# sales_agent        0
# manager            0
# regional_office    0
# dtype: int64

# %% [markdown]
# Com as bases de dados limpas e corrigidas, estamos prontos para avançar para a análise exploratória. Vamos explorar essas bases para extrair insights valiosos. Se houver necessidade de ajuda com alguma análise específica ou visualização de dados, estou à disposição para auxiliar.

# %% [markdown]
# ## Unindo as bases
#
# Observamos que os conjuntos de dados possuem algumas colunas em comum. Portanto, vamos unificá-los em uma única tabela, consolidando nossa análise em um único repositório de dados. Isso facilitará a análise e a geração de insights mais abrangentes. Nesse sentido, vamos criar a base_final, com os dados condensados em um só lugar. A partir dessa base unificada, faremos os tratamentos finais necessários para prosseguir com a análise exploratória de dados (EDA).

# %% [markdown]
# Vamos tentar consolidar os dados em um único conjunto de dados usando a função merge do pandas, o que facilitará a análise ao combinar informações de diferentes conjuntos de dados com base em colunas em comum.

# %%
# Verificando as bases novamente
accounts.head(3)
# Out:
#             account     sector  year_established  revenue  employees  \
# 0  Acme Corporation  technolgy              1996  1100.04       2822
# 1        Betasoloin    medical              1999   251.41        495
# 2          Betatech    medical              1986   647.18       1185
#
#   office_location subsidiary_of
# 0   United States             0
# 1   United States             0
# 2           Kenya             0

# %%
# Verificando as bases novamente
products.head(3)
# Out:
#       product series  sales_price
# 0   GTX Basic    GTX          550
# 1     GTX Pro    GTX         4821
# 2  MG Special     MG           55

# %%
# Verificando as bases novamente
sales_pipeline.head(3)
# Out:
#        sales_agent         product  account deal_stage engage_date  \
# 0      Moses Frase  GTX Plus Basic  Cancity        Won  2016-10-20
# 1  Darcel Schlecht          GTXPro    Isdom        Won  2016-10-25
# 2  Darcel Schlecht      MG Special  Cancity        Won  2016-10-25
#
#    close_date  close_value
# 0  2017-03-01       1054.0
# 1  2017-03-11       4514.0
# 2  2017-03-07         50.0

# %%
# Verificando as bases novamente
sales_team.head(3)
# Out:
#          sales_agent           manager regional_office
# 0      Anna Snelling  Dustin Brinkmann         Central
# 1     Cecily Lampkin  Dustin Brinkmann         Central
# 2  Versie Hillebrand  Dustin Brinkmann         Central

# %% [markdown]
# Como mencionado anteriormente, é possível observar que alguns dados são semelhantes entre as tabelas, como os relacionados aos produtos, agentes de vendas e contas. Portanto, vamos criar um dataset único, unindo as informações dessas tabelas para facilitar nossa análise.

# %% [markdown]
# Antes de realizar a união das tabelas, é essencial verificar se não há erros de digitação ou inconsistências nos dados que possam afetar o merge. Esses erros podem incluir diferenças sutis na forma como os dados são inseridos em diferentes colunas, o que poderia resultar em falhas na combinação das tabelas. Portanto, estamos verificando cuidadosamente os dados para garantir a integridade e a precisão das informações antes de prosseguir com o merge.

# %%
# Conferindo
products['product'].unique()
# Out:
# array(['GTX Basic', 'GTX Pro', 'MG Special', 'MG Advanced',
#        'GTX Plus Pro', 'GTX Plus Basic', 'GTK 500'], dtype=object)

# %%
# Conferindo
sales_pipeline['product'].unique()
# Out:
# array(['GTX Plus Basic', 'GTXPro', 'MG Special', 'GTX Basic',
#        'MG Advanced', 'GTX Plus Pro', 'GTK 500'], dtype=object)

# %% [markdown]
# Na comparação entre as duas listas, apenas o valor 'GTXPro' na segunda lista está escrito de forma diferente em relação a 'GTX Pro' na primeira lista. Todos os outros valores são idênticos.

# %%
# Conferindo
sales_team['sales_agent'].unique()
# Out:
# array(['Anna Snelling', 'Cecily Lampkin', 'Versie Hillebrand',
#        'Lajuana Vencill', 'Moses Frase', 'Jonathan Berthelot',
#        'Marty Freudenburg', 'Gladys Colclough', 'Niesha Huffines',
#        'Darcel Schlecht', 'Mei-Mei Johns', 'Violet Mclelland',
#        'Corliss Cosme', 'Rosie Papadopoulos', 'Garret Kinder',
#        'Wilburn Farren', 'Elizabeth Anderson', 'Daniell Hammack',
#        'Cassey Cress', 'Donn Cantrell', 'Reed Clapper', 'Boris Faz',
#        'Natalya Ivanova', 'Vicki Laflamme', 'Rosalina Dieter',
#        'Hayden Neloms', 'Markita Hansen', 'Elease Gluck',
#        'Carol Thompson', 'James Ascencio', 'Kary Hendrixson',
#        'Kami Bicknell', 'Zane Levy', 'Maureen Marcano', 'Carl Lin'],
#       dtype=object)

# %%
# Conferindo
sales_pipeline['sales_agent'].unique()
# Out:
# array(['Moses Frase', 'Darcel Schlecht', 'Zane Levy', 'Anna Snelling',
#        'Vicki Laflamme', 'Markita Hansen', 'Niesha Huffines',
#        'James Ascencio', 'Gladys Colclough', 'Maureen Marcano',
#        'Hayden Neloms', 'Rosalina Dieter', 'Versie Hillebrand',
#        'Daniell Hammack', 'Elease Gluck', 'Violet Mclelland',
#        'Kami Bicknell', 'Rosie Papadopoulos', 'Kary Hendrixson',
#        'Reed Clapper', 'Wilburn Farren', 'Garret Kinder',
#        'Marty Freudenburg', 'Cassey Cress', 'Lajuana Vencill',
#        'Boris Faz', 'Donn Cantrell', 'Corliss Cosme', 'Cecily Lampkin',
#        'Jonathan Berthelot'], dtype=object)

# %% [markdown]
# - 'Mei-Mei Johns' está apenas na primeira lista.
# - 'Elizabeth Anderson' está apenas na primeira lista.
# - 'Natalya Ivanova' está apenas na primeira lista.
# - 'Carol Thompson' está apenas na primeira lista.
#
# Acredito que essas pessoas são da empresa mas não efetivaram vendas

# %%
# Conferindo
accounts['account'].unique()
# Out:
# array(['Acme Corporation', 'Betasoloin', 'Betatech', 'Bioholding',
#        'Bioplex', 'Blackzim', 'Bluth Company', 'Bubba Gump', 'Cancity',
#        'Cheers', 'Codehow', 'Condax', 'Conecom', 'Dalttechnology',
#        'dambase', 'Domzoom', 'Doncon', 'Donquadtech', 'Dontechi',
#        'Donware', 'Fasehatice', 'Faxquote', 'Finhigh', 'Finjob',
#        'Funholding', 'Ganjaflex', 'Gekko & Co',
#        'Genco Pura Olive Oil Company', 'Globex Corporation', 'Gogozoom',
#        'Golddex', 'Goodsilron', 'Green-Plus', 'Groovestreet', 'Hatfan',
#        'Hottechi', 'Initech', 'Inity', 'Isdom', 'Iselectrics', 'J-Texon',
#        'Kan-code', 'Kinnamplus', 'Konex', 'Konmatfix', 'Labdrill',
#        'Lexiqvolax', 'Massive Dynamic', 'Mathtouch', 'Nam-zim', 'Newex',
#        'Ontomedia', 'Opentech', 'Plexzap', 'Plusstrip', 'Plussunin',
#        'Rangreen', 'Rantouch', 'Ron-tech', 'Rundofase', 'Scotfind',
#        'Scottech', 'Silis', 'Singletechno', 'Sonron', 'Stanredtax',
#        'Statholdings', 'Streethex', 'Sumace', 'Sunnamplex',
#        'The New York Inquirer', 'Toughzap', 'Treequote',
#        'Umbrella Corporation', 'Vehement Capital Partners', 'Warephase',
#        'Xx-holding', 'Xx-zobam', 'Y-corporation', 'Yearin', 'Zathunicon',
#        'Zencorporation', 'Zoomit', 'Zotware', 'Zumgoity'], dtype=object)

# %%
# Conferindo
sales_pipeline['account'].unique()
# Out:
# array(['Cancity', 'Isdom', 'Codehow', 'Hatfan', 'Ron-tech', 'J-Texon',
#        'Cheers', 'Zumgoity', 0, 'Bioholding',
#        'Genco Pura Olive Oil Company', 'Sunnamplex', 'Sonron', 'Finjob',
#        'Scotfind', 'Treequote', 'Xx-zobam', 'Rantouch', 'Fasehatice',
#        'Vehement Capital Partners', 'Warephase', 'Zoomit', 'Ganjaflex',
#        'Labdrill', 'Zotware', 'dambase', 'Xx-holding', 'Acme Corporation',
#        'Green-Plus', 'The New York Inquirer', 'Mathtouch', 'Gogozoom',
#        'Stanredtax', 'Konmatfix', 'Conecom', 'Golddex', 'Plexzap',
#        'Rundofase', 'Finhigh', 'Funholding', 'Opentech', 'Silis',
#        'Goodsilron', 'Rangreen', 'Kan-code', 'Nam-zim', 'Y-corporation',
#        'Bioplex', 'Plusstrip', 'Toughzap', 'Dalttechnology', 'Ontomedia',
#        'Kinnamplus', 'Lexiqvolax', 'Statholdings', 'Umbrella Corporation',
#        'Bubba Gump', 'Faxquote', 'Dontechi', 'Konex', 'Betasoloin',
#        'Domzoom', 'Donquadtech', 'Globex Corporation', 'Plussunin',
#        'Condax', 'Massive Dynamic', 'Doncon', 'Scottech', 'Gekko & Co',
#        'Initech', 'Singletechno', 'Yearin', 'Zathunicon', 'Betatech',
#        'Blackzim', 'Hottechi', 'Inity', 'Sumace', 'Zencorporation',
#        'Groovestreet', 'Donware', 'Streethex', 'Iselectrics', 'Newex',
#        'Bluth Company'], dtype=object)

# %% [markdown]
# Não apresentam nomes incorretos.

# %% [markdown]
# Agora vamos tratar os valores diferentes na coluna 'product' e, em seguida, faremos o merge das bases novamente. Essa etapa é fundamental para garantir que os dados estejam consistentes e prontos para a análise exploratória.

# %%
# Ajustando na base sales_pipeline
sales_pipeline['product'] = sales_pipeline['product'].replace('GTXPro', 'GTX Pro')

# Conferindo
sales_pipeline['product'].unique()
# Out:
# array(['GTX Plus Basic', 'GTX Pro', 'MG Special', 'GTX Basic',
#        'MG Advanced', 'GTX Plus Pro', 'GTK 500'], dtype=object)

# %% [markdown]
# Agora, vamos unir os dados utilizando o método left join para garantir a preservação de todas as informações. O left join é um tipo de junção que combina os registros de duas tabelas com base em uma coluna comum, mantendo todos os registros da tabela à esquerda e adicionando os registros correspondentes da tabela à direita. Quando não há correspondência, o resultado inclui todas as entradas da tabela à esquerda, preenchendo com valores nulos para as colunas da tabela à direita. Esse método é útil para garantir que nenhum dado importante da tabela principal seja excluído.

# %%
# Criando uma cópia do DataFrame sales_pipeline
base_final = sales_pipeline.copy()

# Realizando o merge com base_completa
base_final = pd.merge(base_final, products, on='product', how='left')

# Fazendo o join com o DataFrame sales_team
base_final = pd.merge(sales_pipeline, sales_team, on='sales_agent', how='left')

# Fazendo o join com o DataFrame accounts
base_final = pd.merge(sales_pipeline, accounts, on='account', how='left')

# %%
# Verificando
base_final.head()
# Out:
#        sales_agent         product  account deal_stage engage_date  \
# 0      Moses Frase  GTX Plus Basic  Cancity        Won  2016-10-20
# 1  Darcel Schlecht         GTX Pro    Isdom        Won  2016-10-25
# 2  Darcel Schlecht      MG Special  Cancity        Won  2016-10-25
# 3      Moses Frase       GTX Basic  Codehow        Won  2016-10-25
# 4        Zane Levy       GTX Basic   Hatfan        Won  2016-10-25
#
#    close_date  close_value    sector  year_established  revenue  employees  \
# 0  2017-03-01       1054.0    retail            2001.0   718.62     2448.0
# 1  2017-03-11       4514.0   medical            2002.0  3178.24     4540.0
# 2  2017-03-07         50.0    retail            2001.0   718.62     2448.0
# 3  2017-03-09        588.0  software            1998.0  2714.90     2641.0
# 4  2017-03-02        517.0  services            1982.0   792.46     1299.0
#
#   office_location     subsidiary_of
# 0   United States                 0
# 1   United States                 0
# 2   United States                 0
# 3   United States  Acme Corporation
# 4   United States                 0

# %%
# Verificando
base_final.shape
# Out:
# (8448, 13)

# %% [markdown]
# Percebe-se a falta das colunas referentes aos produtos. vamos adicioná-la

# %%
# Trazendo dados anteriores sobre os produtos vendidos.
# Dicionário com os dados associados a cada produto
produtos_associados = {
    'GTX Basic': {'series': 'GTX', 'sales_price': 550},
    'GTX Pro': {'series': 'GTX', 'sales_price': 4821},
    'MG Special': {'series': 'MG', 'sales_price': 55},
    'MG Advanced': {'series': 'MG', 'sales_price': 3393},
    'GTX Plus Pro': {'series': 'GTX', 'sales_price': 5482},
    'GTX Plus Basic': {'series': 'GTX', 'sales_price': 1096},
    'GTK 500': {'series': 'GTK', 'sales_price': 26768}
}

# Mapeando os valores da coluna 'product' para os dados associados
base_final['series'] = base_final['product'].map(lambda x: produtos_associados[x]['series'] if x in produtos_associados else None)
base_final['sales_price'] = base_final['product'].map(lambda x: produtos_associados[x]['sales_price'] if x in produtos_associados else None)

# %%
# Verificando
base_final.head()
# Out:
#        sales_agent         product  account deal_stage engage_date  \
# 0      Moses Frase  GTX Plus Basic  Cancity        Won  2016-10-20
# 1  Darcel Schlecht         GTX Pro    Isdom        Won  2016-10-25
# 2  Darcel Schlecht      MG Special  Cancity        Won  2016-10-25
# 3      Moses Frase       GTX Basic  Codehow        Won  2016-10-25
# 4        Zane Levy       GTX Basic   Hatfan        Won  2016-10-25
#
#    close_date  close_value    sector  year_established  revenue  employees  \
# 0  2017-03-01       1054.0    retail            2001.0   718.62     2448.0
# 1  2017-03-11       4514.0   medical            2002.0  3178.24     4540.0
# 2  2017-03-07         50.0    retail            2001.0   718.62     2448.0
# 3  2017-03-09        588.0  software            1998.0  2714.90     2641.0
# 4  2017-03-02        517.0  services            1982.0   792.46     1299.0
#
#   office_location     subsidiary_of series  sales_price
# 0   United States                 0    GTX         1096
# 1   United States                 0    GTX         4821
# 2   United States                 0     MG           55
# 3   United States  Acme Corporation    GTX          550
# 4   United States                 0    GTX          550

# %%
# Verificando
base_final.shape
# Out:
# (8448, 15)

# %%
# Verificando
base_final[base_final.duplicated()]
# Out:
# Empty DataFrame
# Columns: [sales_agent, product, account, deal_stage, engage_date, close_date, close_value, sector, year_established, revenue, employees, office_location, subsidiary_of, series, sales_price]
# Index: []

# %%
# Verificando
base_final.isnull().sum()
# Out:
# sales_agent            0
# product                0
# account                0
# deal_stage             0
# engage_date            0
# close_date             0
# close_value            0
# sector              1079
# year_established    1079
# revenue             1079
# employees           1079
# office_location     1079
# subsidiary_of       1079
# series                 0
# sales_price            0
# dtype: int64

# %% [markdown]
# Não existem dados duplicados. Contudo, após a junção, percebe-se a existencia de mais dados nulos, provavelmente vindos de um merge que não conseguiu fazer a associação corretamente. Vamos novamente tratar coluna por coluna.

# %%
# Verificando
base_final[base_final['sector'].isnull()]
# Out:
#             sales_agent         product account   deal_stage engage_date  \
# 9        James Ascencio     MG Advanced       0     Engaging  2016-11-03
# 42        Kami Bicknell       GTX Basic       0     Engaging  2016-11-14
# 44         Cassey Cress         GTX Pro       0     Engaging  2016-11-16
# 56        Kami Bicknell  GTX Plus Basic       0     Engaging  2016-11-19
# 60        Hayden Neloms     MG Advanced       0     Engaging  2016-11-20
# ...                 ...             ...     ...          ...         ...
# 8433  Versie Hillebrand       GTX Basic       0  Prospecting           0
# 8435  Versie Hillebrand  GTX Plus Basic       0  Prospecting           0
# 8436  Versie Hillebrand    GTX Plus Pro       0  Prospecting           0
# 8444  Versie Hillebrand      MG Special       0  Prospecting           0
# 8447  Versie Hillebrand     MG Advanced       0  Prospecting           0
#
#      close_date  close_value sector  year_established  revenue  employees  \
# 9             0          0.0    NaN               NaN      NaN        NaN
# 42            0          0.0    NaN               NaN      NaN        NaN
# 44            0          0.0    NaN               NaN      NaN        NaN
# 56            0          0.0    NaN               NaN      NaN        NaN
# 60            0          0.0    NaN               NaN      NaN        NaN
# ...         ...          ...    ...               ...      ...        ...
# 8433          0          0.0    NaN               NaN      NaN        NaN
# 8435          0          0.0    NaN               NaN      NaN        NaN
# 8436          0          0.0    NaN               NaN      NaN        NaN
# 8444          0          0.0    NaN               NaN      NaN        NaN
# 8447          0          0.0    NaN               NaN      NaN        NaN
#
#      office_location subsidiary_of series  sales_price
# 9                NaN           NaN     MG         3393
# 42               NaN           NaN    GTX          550
# 44               NaN           NaN    GTX         4821
# 56               NaN           NaN    GTX         1096
# 60               NaN           NaN     MG         3393
# ...              ...           ...    ...          ...
# 8433             NaN           NaN    GTX          550
# 8435             NaN           NaN    GTX         1096
# 8436             NaN           NaN    GTX         5482
# 8444             NaN           NaN     MG           55
# 8447             NaN           NaN     MG         3393
#
# [1079 rows x 15 columns]

# %%
# Verificando
base_final[base_final['year_established'].isnull()]
# Out:
#             sales_agent         product account   deal_stage engage_date  \
# 9        James Ascencio     MG Advanced       0     Engaging  2016-11-03
# 42        Kami Bicknell       GTX Basic       0     Engaging  2016-11-14
# 44         Cassey Cress         GTX Pro       0     Engaging  2016-11-16
# 56        Kami Bicknell  GTX Plus Basic       0     Engaging  2016-11-19
# 60        Hayden Neloms     MG Advanced       0     Engaging  2016-11-20
# ...                 ...             ...     ...          ...         ...
# 8433  Versie Hillebrand       GTX Basic       0  Prospecting           0
# 8435  Versie Hillebrand  GTX Plus Basic       0  Prospecting           0
# 8436  Versie Hillebrand    GTX Plus Pro       0  Prospecting           0
# 8444  Versie Hillebrand      MG Special       0  Prospecting           0
# 8447  Versie Hillebrand     MG Advanced       0  Prospecting           0
#
#      close_date  close_value sector  year_established  revenue  employees  \
# 9             0          0.0    NaN               NaN      NaN        NaN
# 42            0          0.0    NaN               NaN      NaN        NaN
# 44            0          0.0    NaN               NaN      NaN        NaN
# 56            0          0.0    NaN               NaN      NaN        NaN
# 60            0          0.0    NaN               NaN      NaN        NaN
# ...         ...          ...    ...               ...      ...        ...
# 8433          0          0.0    NaN               NaN      NaN        NaN
# 8435          0          0.0    NaN               NaN      NaN        NaN
# 8436          0          0.0    NaN               NaN      NaN        NaN
# 8444          0          0.0    NaN               NaN      NaN        NaN
# 8447          0          0.0    NaN               NaN      NaN        NaN
#
#      office_location subsidiary_of series  sales_price
# 9                NaN           NaN     MG         3393
# 42               NaN           NaN    GTX          550
# 44               NaN           NaN    GTX         4821
# 56               NaN           NaN    GTX         1096
# 60               NaN           NaN     MG         3393
# ...              ...           ...    ...          ...
# 8433             NaN           NaN    GTX          550
# 8435             NaN           NaN    GTX         1096
# 8436             NaN           NaN    GTX         5482
# 8444             NaN           NaN     MG           55
# 8447             NaN           NaN     MG         3393
#
# [1079 rows x 15 columns]

# %%
# Verificando
base_final[base_final['revenue'].isnull()]
# Out:
#             sales_agent         product account   deal_stage engage_date  \
# 9        James Ascencio     MG Advanced       0     Engaging  2016-11-03
# 42        Kami Bicknell       GTX Basic       0     Engaging  2016-11-14
# 44         Cassey Cress         GTX Pro       0     Engaging  2016-11-16
# 56        Kami Bicknell  GTX Plus Basic       0     Engaging  2016-11-19
# 60        Hayden Neloms     MG Advanced       0     Engaging  2016-11-20
# ...                 ...             ...     ...          ...         ...
# 8433  Versie Hillebrand       GTX Basic       0  Prospecting           0
# 8435  Versie Hillebrand  GTX Plus Basic       0  Prospecting           0
# 8436  Versie Hillebrand    GTX Plus Pro       0  Prospecting           0
# 8444  Versie Hillebrand      MG Special       0  Prospecting           0
# 8447  Versie Hillebrand     MG Advanced       0  Prospecting           0
#
#      close_date  close_value sector  year_established  revenue  employees  \
# 9             0          0.0    NaN               NaN      NaN        NaN
# 42            0          0.0    NaN               NaN      NaN        NaN
# 44            0          0.0    NaN               NaN      NaN        NaN
# 56            0          0.0    NaN               NaN      NaN        NaN
# 60            0          0.0    NaN               NaN      NaN        NaN
# ...         ...          ...    ...               ...      ...        ...
# 8433          0          0.0    NaN               NaN      NaN        NaN
# 8435          0          0.0    NaN               NaN      NaN        NaN
# 8436          0          0.0    NaN               NaN      NaN        NaN
# 8444          0          0.0    NaN               NaN      NaN        NaN
# 8447          0          0.0    NaN               NaN      NaN        NaN
#
#      office_location subsidiary_of series  sales_price
# 9                NaN           NaN     MG         3393
# 42               NaN           NaN    GTX          550
# 44               NaN           NaN    GTX         4821
# 56               NaN           NaN    GTX         1096
# 60               NaN           NaN     MG         3393
# ...              ...           ...    ...          ...
# 8433             NaN           NaN    GTX          550
# 8435             NaN           NaN    GTX         1096
# 8436             NaN           NaN    GTX         5482
# 8444             NaN           NaN     MG           55
# 8447             NaN           NaN     MG         3393
#
# [1079 rows x 15 columns]

# %%
# Verificando
base_final[base_final['employees'].isnull()]
# Out:
#             sales_agent         product account   deal_stage engage_date  \
# 9        James Ascencio     MG Advanced       0     Engaging  2016-11-03
# 42        Kami Bicknell       GTX Basic       0     Engaging  2016-11-14
# 44         Cassey Cress         GTX Pro       0     Engaging  2016-11-16
# 56        Kami Bicknell  GTX Plus Basic       0     Engaging  2016-11-19
# 60        Hayden Neloms     MG Advanced       0     Engaging  2016-11-20
# ...                 ...             ...     ...          ...         ...
# 8433  Versie Hillebrand       GTX Basic       0  Prospecting           0
# 8435  Versie Hillebrand  GTX Plus Basic       0  Prospecting           0
# 8436  Versie Hillebrand    GTX Plus Pro       0  Prospecting           0
# 8444  Versie Hillebrand      MG Special       0  Prospecting           0
# 8447  Versie Hillebrand     MG Advanced       0  Prospecting           0
#
#      close_date  close_value sector  year_established  revenue  employees  \
# 9             0          0.0    NaN               NaN      NaN        NaN
# 42            0          0.0    NaN               NaN      NaN        NaN
# 44            0          0.0    NaN               NaN      NaN        NaN
# 56            0          0.0    NaN               NaN      NaN        NaN
# 60            0          0.0    NaN               NaN      NaN        NaN
# ...         ...          ...    ...               ...      ...        ...
# 8433          0          0.0    NaN               NaN      NaN        NaN
# 8435          0          0.0    NaN               NaN      NaN        NaN
# 8436          0          0.0    NaN               NaN      NaN        NaN
# 8444          0          0.0    NaN               NaN      NaN        NaN
# 8447          0          0.0    NaN               NaN      NaN        NaN
#
#      office_location subsidiary_of series  sales_price
# 9                NaN           NaN     MG         3393
# 42               NaN           NaN    GTX          550
# 44               NaN           NaN    GTX         4821
# 56               NaN           NaN    GTX         1096
# 60               NaN           NaN     MG         3393
# ...              ...           ...    ...          ...
# 8433             NaN           NaN    GTX          550
# 8435             NaN           NaN    GTX         1096
# 8436             NaN           NaN    GTX         5482
# 8444             NaN           NaN     MG           55
# 8447             NaN           NaN     MG         3393
#
# [1079 rows x 15 columns]

# %%
# Verificando
base_final[base_final['office_location'].isnull()]
# Out:
#             sales_agent         product account   deal_stage engage_date  \
# 9        James Ascencio     MG Advanced       0     Engaging  2016-11-03
# 42        Kami Bicknell       GTX Basic       0     Engaging  2016-11-14
# 44         Cassey Cress         GTX Pro       0     Engaging  2016-11-16
# 56        Kami Bicknell  GTX Plus Basic       0     Engaging  2016-11-19
# 60        Hayden Neloms     MG Advanced       0     Engaging  2016-11-20
# ...                 ...             ...     ...          ...         ...
# 8433  Versie Hillebrand       GTX Basic       0  Prospecting           0
# 8435  Versie Hillebrand  GTX Plus Basic       0  Prospecting           0
# 8436  Versie Hillebrand    GTX Plus Pro       0  Prospecting           0
# 8444  Versie Hillebrand      MG Special       0  Prospecting           0
# 8447  Versie Hillebrand     MG Advanced       0  Prospecting           0
#
#      close_date  close_value sector  year_established  revenue  employees  \
# 9             0          0.0    NaN               NaN      NaN        NaN
# 42            0          0.0    NaN               NaN      NaN        NaN
# 44            0          0.0    NaN               NaN      NaN        NaN
# 56            0          0.0    NaN               NaN      NaN        NaN
# 60            0          0.0    NaN               NaN      NaN        NaN
# ...         ...          ...    ...               ...      ...        ...
# 8433          0          0.0    NaN               NaN      NaN        NaN
# 8435          0          0.0    NaN               NaN      NaN        NaN
# 8436          0          0.0    NaN               NaN      NaN        NaN
# 8444          0          0.0    NaN               NaN      NaN        NaN
# 8447          0          0.0    NaN               NaN      NaN        NaN
#
#      office_location subsidiary_of series  sales_price
# 9                NaN           NaN     MG         3393
# 42               NaN           NaN    GTX          550
# 44               NaN           NaN    GTX         4821
# 56               NaN           NaN    GTX         1096
# 60               NaN           NaN     MG         3393
# ...              ...           ...    ...          ...
# 8433             NaN           NaN    GTX          550
# 8435             NaN           NaN    GTX         1096
# 8436             NaN           NaN    GTX         5482
# 8444             NaN           NaN     MG           55
# 8447             NaN           NaN     MG         3393
#
# [1079 rows x 15 columns]

# %%
# Verificando
base_final[base_final['subsidiary_of'].isnull()]
# Out:
#             sales_agent         product account   deal_stage engage_date  \
# 9        James Ascencio     MG Advanced       0     Engaging  2016-11-03
# 42        Kami Bicknell       GTX Basic       0     Engaging  2016-11-14
# 44         Cassey Cress         GTX Pro       0     Engaging  2016-11-16
# 56        Kami Bicknell  GTX Plus Basic       0     Engaging  2016-11-19
# 60        Hayden Neloms     MG Advanced       0     Engaging  2016-11-20
# ...                 ...             ...     ...          ...         ...
# 8433  Versie Hillebrand       GTX Basic       0  Prospecting           0
# 8435  Versie Hillebrand  GTX Plus Basic       0  Prospecting           0
# 8436  Versie Hillebrand    GTX Plus Pro       0  Prospecting           0
# 8444  Versie Hillebrand      MG Special       0  Prospecting           0
# 8447  Versie Hillebrand     MG Advanced       0  Prospecting           0
#
#      close_date  close_value sector  year_established  revenue  employees  \
# 9             0          0.0    NaN               NaN      NaN        NaN
# 42            0          0.0    NaN               NaN      NaN        NaN
# 44            0          0.0    NaN               NaN      NaN        NaN
# 56            0          0.0    NaN               NaN      NaN        NaN
# 60            0          0.0    NaN               NaN      NaN        NaN
# ...         ...          ...    ...               ...      ...        ...
# 8433          0          0.0    NaN               NaN      NaN        NaN
# 8435          0          0.0    NaN               NaN      NaN        NaN
# 8436          0          0.0    NaN               NaN      NaN        NaN
# 8444          0          0.0    NaN               NaN      NaN        NaN
# 8447          0          0.0    NaN               NaN      NaN        NaN
#
#      office_location subsidiary_of series  sales_price
# 9                NaN           NaN     MG         3393
# 42               NaN           NaN    GTX          550
# 44               NaN           NaN    GTX         4821
# 56               NaN           NaN    GTX         1096
# 60               NaN           NaN     MG         3393
# ...              ...           ...    ...          ...
# 8433             NaN           NaN    GTX          550
# 8435             NaN           NaN    GTX         1096
# 8436             NaN           NaN    GTX         5482
# 8444             NaN           NaN     MG           55
# 8447             NaN           NaN     MG         3393
#
# [1079 rows x 15 columns]

# %% [markdown]
# Novamente percebe-se que os dados ausentes são referentes a negocios não efetivados e que não tiveram informações suficientes. Vamos substituir todos os dados faltantes por 0

# %%
# Substituindo
base_final['sector'].fillna(0, inplace=True)
base_final['year_established'].fillna(0, inplace=True)
base_final['revenue'].fillna(0, inplace=True)
base_final['employees'].fillna(0, inplace=True)
base_final['office_location'].fillna(0, inplace=True)
base_final['subsidiary_of'].fillna(0, inplace=True)

# Verificando
base_final.isnull().sum()
# Out:
# sales_agent         0
# product             0
# account             0
# deal_stage          0
# engage_date         0
# close_date          0
# close_value         0
# sector              0
# year_established    0
# revenue             0
# employees           0
# office_location     0
# subsidiary_of       0
# series              0
# sales_price         0
# dtype: int64

# %% [markdown]
# Nota-se que nem todas as 16 colunas são relevantes para a análise. Portanto, vamos realizar uma engenharia de atributos para selecionar apenas os atributos mais importantes.

# %%
# Conferindo a base
base_final.head()
# Out:
#        sales_agent         product  account deal_stage engage_date  \
# 0      Moses Frase  GTX Plus Basic  Cancity        Won  2016-10-20
# 1  Darcel Schlecht         GTX Pro    Isdom        Won  2016-10-25
# 2  Darcel Schlecht      MG Special  Cancity        Won  2016-10-25
# 3      Moses Frase       GTX Basic  Codehow        Won  2016-10-25
# 4        Zane Levy       GTX Basic   Hatfan        Won  2016-10-25
#
#    close_date  close_value    sector  year_established  revenue  employees  \
# 0  2017-03-01       1054.0    retail            2001.0   718.62     2448.0
# 1  2017-03-11       4514.0   medical            2002.0  3178.24     4540.0
# 2  2017-03-07         50.0    retail            2001.0   718.62     2448.0
# 3  2017-03-09        588.0  software            1998.0  2714.90     2641.0
# 4  2017-03-02        517.0  services            1982.0   792.46     1299.0
#
#   office_location     subsidiary_of series  sales_price
# 0   United States                 0    GTX         1096
# 1   United States                 0    GTX         4821
# 2   United States                 0     MG           55
# 3   United States  Acme Corporation    GTX          550
# 4   United States                 0    GTX          550

# %% [markdown]
# Vamos ajustar as datas para analisar o número de dias gastos para efetivar ou não uma compra. Primeiramente, substituiremos '0' por NaN nas colunas 'engage_date' e 'close_date' para indicar a ausência de uma data válida. Em seguida, converteremos essas colunas para o formato datetime para garantir o tratamento correto das datas. Por fim, calcularemos a diferença em dias entre 'close_date' e 'engage_date' e criaremos a nova coluna 'days_to_close' para armazenar essa informação.

# %%
# Ajustando aas datas

# Substitua '0' por NaN
base_final['engage_date'] = base_final['engage_date'].replace('0', np.nan)
base_final['close_date'] = base_final['close_date'].replace('0', np.nan)

# Converta as colunas de data para o formato datetime
base_final['engage_date'] = pd.to_datetime(base_final['engage_date'], errors='coerce')
base_final['close_date'] = pd.to_datetime(base_final['close_date'], errors='coerce')

# Calculando a diferença em dias e criando a nova coluna
base_final['time_until_close'] = (base_final['close_date'] - base_final['engage_date']).dt.days

# %%
# Verificando
base_final.head()
# Out:
#        sales_agent         product  account deal_stage engage_date close_date  \
# 0      Moses Frase  GTX Plus Basic  Cancity        Won  2016-10-20 2017-03-01
# 1  Darcel Schlecht         GTX Pro    Isdom        Won  2016-10-25 2017-03-11
# 2  Darcel Schlecht      MG Special  Cancity        Won  2016-10-25 2017-03-07
# 3      Moses Frase       GTX Basic  Codehow        Won  2016-10-25 2017-03-09
# 4        Zane Levy       GTX Basic   Hatfan        Won  2016-10-25 2017-03-02
#
#    close_value    sector  year_established  revenue  employees  \
# 0       1054.0    retail            2001.0   718.62     2448.0
# 1       4514.0   medical            2002.0  3178.24     4540.0
# 2         50.0    retail            2001.0   718.62     2448.0
# 3        588.0  software            1998.0  2714.90     2641.0
# 4        517.0  services            1982.0   792.46     1299.0
#
#   office_location     subsidiary_of series  sales_price  time_until_close
# 0   United States                 0    GTX         1096             132.0
# 1   United States                 0    GTX         4821             137.0
# 2   United States                 0     MG           55             133.0
# 3   United States  Acme Corporation    GTX          550             135.0
# 4   United States                 0    GTX          550             128.0

# %%
# Verificando
base_final.isnull().sum()
# Out:
# sales_agent            0
# product                0
# account                0
# deal_stage             0
# engage_date          213
# close_date          1737
# close_value            0
# sector                 0
# year_established       0
# revenue                0
# employees              0
# office_location        0
# subsidiary_of          0
# series                 0
# sales_price            0
# time_until_close    1737
# dtype: int64

# %% [markdown]
# Novamente, precisamos lidar com as datas que não informadas devido ao não fechamento do negocio. Vamos preencher esses dados faltantes com 0 e então eliminar as colunas de data de engajamento e data de fechamento

# %%
# Substituindo
base_final['engage_date'].fillna(0, inplace=True)
base_final['close_date'].fillna(0, inplace=True)
base_final['time_until_close'].fillna(0, inplace=True)

# %%
# Excluindo colunas desnecessárias
base_final.drop('engage_date', axis=1, inplace=True)
base_final.drop('close_date', axis=1, inplace=True)

# %%
# Conferindo
base_final.head()
# Out:
#        sales_agent         product  account deal_stage  close_value    sector  \
# 0      Moses Frase  GTX Plus Basic  Cancity        Won       1054.0    retail
# 1  Darcel Schlecht         GTX Pro    Isdom        Won       4514.0   medical
# 2  Darcel Schlecht      MG Special  Cancity        Won         50.0    retail
# 3      Moses Frase       GTX Basic  Codehow        Won        588.0  software
# 4        Zane Levy       GTX Basic   Hatfan        Won        517.0  services
#
#    year_established  revenue  employees office_location     subsidiary_of  \
# 0            2001.0   718.62     2448.0   United States                 0
# 1            2002.0  3178.24     4540.0   United States                 0
# 2            2001.0   718.62     2448.0   United States                 0
# 3            1998.0  2714.90     2641.0   United States  Acme Corporation
# 4            1982.0   792.46     1299.0   United States                 0
#
#   series  sales_price  time_until_close
# 0    GTX         1096             132.0
# 1    GTX         4821             137.0
# 2     MG           55             133.0
# 3    GTX          550             135.0
# 4    GTX          550             128.0

# %% [markdown]
# Observamos a falta de dados sobre o sales team. Para corrigir isso, vamos adicionar essas informações à nossa análise.

# %%
# Adicionando
base_final = pd.merge(base_final, sales_team, on='sales_agent', how='left')

# %%
# Conferindo
base_final.head()
# Out:
#        sales_agent         product  account deal_stage  close_value    sector  \
# 0      Moses Frase  GTX Plus Basic  Cancity        Won       1054.0    retail
# 1  Darcel Schlecht         GTX Pro    Isdom        Won       4514.0   medical
# 2  Darcel Schlecht      MG Special  Cancity        Won         50.0    retail
# 3      Moses Frase       GTX Basic  Codehow        Won        588.0  software
# 4        Zane Levy       GTX Basic   Hatfan        Won        517.0  services
#
#    year_established  revenue  employees office_location     subsidiary_of  \
# 0            2001.0   718.62     2448.0   United States                 0
# 1            2002.0  3178.24     4540.0   United States                 0
# 2            2001.0   718.62     2448.0   United States                 0
# 3            1998.0  2714.90     2641.0   United States  Acme Corporation
# 4            1982.0   792.46     1299.0   United States                 0
#
#   series  sales_price  time_until_close           manager regional_office
# 0    GTX         1096             132.0  Dustin Brinkmann         Central
# 1    GTX         4821             137.0     Melvin Marxen         Central
# 2     MG           55             133.0     Melvin Marxen         Central
# 3    GTX          550             135.0  Dustin Brinkmann         Central
# 4    GTX          550             128.0     Summer Sewald            West

# %%
# Verificando
base_final.shape
# Out:
# (8448, 16)

# %% [markdown]
# Após concluir a montagem e tratamento da base final, vamos salvá-la no formato csv para seguir para EDA que está localizada nesse [notebook](https://colab.research.google.com/drive/1yI6cAagZ73nXlJZU8yMFmRG80vdYWyof).

# %%
# Salvando a base
base_final.to_csv('base_final.csv', index=True)
